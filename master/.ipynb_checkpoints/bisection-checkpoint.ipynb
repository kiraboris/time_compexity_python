# %% [markdown]
# **Bisection (binary search) in sorted lists**
# -----

# %% [markdown]
# **Problem:**
# Find experimental (obs) peaks nearest to a predicted (calc) transition by their frequency value.
# Let the calc frequency be _x_ and the obs frequencies be _freq_ == [...],  len(_freq_) = _n_.
#
# **Naive idea:**
# Check each _f in freq_ to be near _x_ in O(_n_) time.
#
# **Bisection:**
# If _freq_ is sorted, recursively divide it in halfs and find the insertion position of _x_ into _freq_ to be between _i_ and _i + 1_.<br>
# These positions indicate the two nearest experimental peaks.
# We only have to take O(log(_n_)) steps.

# %%
import random
import bisect

N = 200000
biglist_sorted =  sorted((random.randint(0, 100) for _ in range(0, N)))

def prepare(n):
    return biglist_sorted[:n]
    
def sorted_append_1(lst, n):
    lst.append(42)
    lst.sort()

def sorted_append_2(lst, n):
    i = bisect.bisect_left(lst, 42)
    lst.insert(i, 42)

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

def plot_time_vs_n(Test, N = 50000, T = 20):
    xxx = []
    yyy = []
    for n in range(N//10, N, 500):
        tests = [Test(n) for _ in range(0, T)]
        t1 =  time.process_time()
        for i in range(0, T):
            tests[i].run()
        t2 =  time.process_time()
        xxx.append(n)
        yyy.append((t2-t1)/T*1e6)
    
    plt.xlabel("n")
    plt.ylabel("time / usec")
    return plt.plot(xxx, yyy)

# %%
plot_time_vs_n(prepare, sorted_append_1, N=N, T=5)
plot_time_vs_n(prepare, sorted_append_2,  N=N, T=5)
plt.ylim(bottom=0.0, top = 0.02)
plt.show()
